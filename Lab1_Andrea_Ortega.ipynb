# %% [markdown]
# ## Nociception Monitors
#
# Taking advantage of the assignment of the TFG, I take advantage to do this work on the nociception monitors.

# %%
import matplotlib.pyplot as plt

# Made up data for the last 50 years
years = range(1973, 2023)
uso_nociceptores = [10, 12, 13, 15, 16, 18, 19, 20, 22, 23, 25, 27, 28, 30, 32, 34, 35, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80, 82, 84, 86, 88, 90, 92, 94, 96, 98, 100]

# Create the chart
plt.plot(years, uso_nociceptores, marker='o', linestyle='-', color='b')

# Configure the graph
plt.title("Use of nociceptoion monitors in surgeries over the years")
plt.xlabel("Years")
plt.ylabel("Use of nociceptoion monitors")

# show the graph
plt.show()

# %% [markdown]
# > **Warning**: the data is invented.
